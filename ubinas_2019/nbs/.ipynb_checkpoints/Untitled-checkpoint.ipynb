# %%
# %load_ext autoreload
# %autoreload 2

# %%
from useful_scit.imps import *

# %%
sys.path.append('../../../ubinas-2019/')

# %%
from ubinas_2019.util import *
import ubinas_2019.util

# %%
ds = get_joined_ds()

# %%
fig,ax = plt.subplots()
ax.scatter(C_SO2,C_SO4,alpha=.05,data=ds)

# %%
ax.set_xlim(.01,100)
ax.set_ylim(.01,100)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(C_SO2)
ax.set_ylabel(C_SO4)

ax.figure

# %%
ds4 = import_acsm_data()

# %%
ds = get_joined_ds()

# %%
import matplotlib.dates as mdates
ax = ds[[C_SO4,C_SO2]].plot(figsize=(20,10),style='.',alpha=.2)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.figure.autofmt_xdate()
ax.grid(True,'both')

# %%
fig,ax = plt.subplots()
# ax.plot(ds.index.values,ds[C_SO2].values)

# %%
dt = pd.to_datetime(import_so2_data()['unix_sec_local']*10**9)

# %%
data = pd.read_csv(SO2_MON_PATH)
unix_col = 'unix_sec_local'
local_time= pd.to_datetime(data[unix_col]*10**9)
data[C_LT] = local_time
data = data.set_index(C_LT)
# data = data.drop(unix_col, axis=1)
data = data.rename(str,columns={'so2_corrected[ppb]':C_SO2})

# %%
data.set_index(local_time).index
# Out:
# DatetimeIndex(['2019-05-02 17:05:00', '2019-05-02 17:06:00',
#                '2019-05-02 17:07:00', '2019-05-02 17:08:00',
#                '2019-05-02 17:09:00', '2019-05-02 17:10:00',
#                '2019-05-02 17:11:00', '2019-05-02 17:12:00',
#                '2019-05-02 17:13:00', '2019-05-02 17:14:00',
#                ...
#                '2019-07-08 14:36:00', '2019-07-08 14:37:00',
#                '2019-07-08 14:38:00', '2019-07-08 14:39:00',
#                '2019-07-08 14:40:00', '2019-07-08 14:41:00',
#                '2019-07-08 14:42:00', '2019-07-08 14:43:00',
#                '2019-07-08 14:44:00', '2019-07-08 14:45:00'],
#               dtype='datetime64[ns]', name='unix_sec_local', length=125562, freq=None)

# %%
data = import_so2_data()

# %%
data.index
# Out:
# DatetimeIndex(['2019-05-02 17:05:00', '2019-05-02 17:06:00',
#                '2019-05-02 17:07:00', '2019-05-02 17:08:00',
#                '2019-05-02 17:09:00', '2019-05-02 17:10:00',
#                '2019-05-02 17:11:00', '2019-05-02 17:12:00',
#                '2019-05-02 17:13:00', '2019-05-02 17:14:00',
#                ...
#                '2019-07-08 14:36:00', '2019-07-08 14:37:00',
#                '2019-07-08 14:38:00', '2019-07-08 14:39:00',
#                '2019-07-08 14:40:00', '2019-07-08 14:41:00',
#                '2019-07-08 14:42:00', '2019-07-08 14:43:00',
#                '2019-07-08 14:44:00', '2019-07-08 14:45:00'],
#               dtype='datetime64[ns]', name='local_time', length=125562, freq=None)

# %%
data.index = pd.to_datetime(data.index)

# %%
data.index
# Out:
# DatetimeIndex(['2019-05-02 17:05:00', '2019-05-02 17:06:00',
#                '2019-05-02 17:07:00', '2019-05-02 17:08:00',
#                '2019-05-02 17:09:00', '2019-05-02 17:10:00',
#                '2019-05-02 17:11:00', '2019-05-02 17:12:00',
#                '2019-05-02 17:13:00', '2019-05-02 17:14:00',
#                ...
#                '2019-07-08 14:36:00', '2019-07-08 14:37:00',
#                '2019-07-08 14:38:00', '2019-07-08 14:39:00',
#                '2019-07-08 14:40:00', '2019-07-08 14:41:00',
#                '2019-07-08 14:42:00', '2019-07-08 14:43:00',
#                '2019-07-08 14:44:00', '2019-07-08 14:45:00'],
#               dtype='datetime64[ns]', name='local_time', length=125562, freq=None)
